# %%
import os
import pandas as pd
from glob import glob

# %%
df = pd.read_csv("./trusted/trusted_datatran.csv")

print("Dados do datatran: ", df.head())
# Out:
# Dados do datatran:         ID        DATA   DIA_SEMANA   HORARIO ESTADO   MUNICIPIO  \
# 0  331693  2021-01-01  sexta-feira  00:02:00     SC      LAGUNA
# 1  331694  2021-01-01  sexta-feira  00:15:00     PR    MARIALVA
# 2  331696  2021-01-01  sexta-feira  00:00:00     SP     TAUBATE
# 3  331699  2021-01-01  sexta-feira  01:20:00     SC  NAVEGANTES
# 4  331701  2021-01-01  sexta-feira  00:30:00     PE    IGARASSU
#
#                              CAUSA_ACIDENTE       TIPO_ACIDENTE  \
# 0          Ingestão de álcool pelo condutor    Colisão traseira
# 1                   Velocidade Incompatível  Colisão com objeto
# 2      Demais falhas mecânicas ou elétricas            Incêndio
# 3               Manobra de mudança de faixa     Colisão lateral
# 4  Reação tardia ou ineficiente do condutor    Colisão traseira
#
#   CLASSIFICACAO_ACIDENTE     FASE_DIA  ... CONDICAO_METEREOLOGICA TIPO_PISTA  \
# 0    Com Vítimas Feridas  Plena Noite  ...                Nublado      Dupla
# 1    Com Vítimas Feridas  Plena Noite  ...              Céu Claro      Dupla
# 2            Sem Vítimas  Plena Noite  ...                Nublado      Dupla
# 3    Com Vítimas Feridas  Plena Noite  ...                Nublado   Múltipla
# 4    Com Vítimas Feridas  Plena Noite  ...                  Chuva   Múltipla
#
#          TRACADO_VIA PESSOAS  MORTOS  ILESOS  FERIDOS  VEICULOS  REGIONAL MES
# 0               Reta       3       0       2        1         2     SR-SC   1
# 1               Reta       2       0       0        2         1     SR-PR   1
# 2               Reta       1       0       1        0         1     SR-SP   1
# 3              Curva       3       0       1        2         2     SR-SC   1
# 4  Desvio Temporário       2       0       1        1         2     SR-PE   1
#
# [5 rows x 21 columns]

# %%
# Pegando os dados de acidentes de trânsito apenas do estado de São Paulo
df = df[df["ESTADO"] == "SP"]

df.to_csv("./refined/refined_datatran_sp.csv", index=False)

# %%
# Pegando os dados de acidentes de trânsito do estado de São Paulo com falhas mecânicas ou elétricas como causa do acidente
df_final = df[
    (df["ESTADO"] == "SP") &
    (df["CAUSA_ACIDENTE"] == "Demais falhas mecânicas ou elétricas")
]

df_final.to_csv("./refined/refined_datatran_sp_falhas_mecanicas.csv", index=False)
